# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Bank customers.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %% [markdown]
# ## START MANIPULATION

# %%
## CHANGE SOME COLUMN NAMES FOR EASY UNDERSTANDING

# %%
df.columns.tolist()
# Out:
# ['CLIENTNUM',
#  'Attrition_Flag',
#  'Customer_Age',
#  'Gender',
#  'Dependent_count',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category',
#  'Months_on_book',
#  'Total_Relationship_Count',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Amt_Chng_Q4_Q1',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Total_Ct_Chng_Q4_Q1',
#  'Avg_Utilization_Ratio']

# %%
df.rename(columns={'Attrition_Flag': 'Attrition_Status'}, inplace=True)
df.rename(columns={'CLIENTNUM': 'Client_Number'}, inplace=True)
df.rename(columns={'Income_Category': 'Income_Per_Annum'}, inplace=True)
df.rename(columns={'Months_Inactive_12_mon': 'Months_Inactive'}, inplace=True)
df.rename(columns={'Contacts_Count_12_mon': 'Contacts_Count'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Client_Number', 'Attrition_Status', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Per_Annum', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive', 'Contacts_Count',
#        'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy',
#        'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct',
#        'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
## DROP SOME UNNECCESSARY COLUMNS THAT WILL

# %%
columns_to_drop = ['Avg_Utilization_Ratio', 'Total_Ct_Chng_Q4_Q1','Total_Amt_Chng_Q4_Q1']

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.columns
# Out:
# Index(['Client_Number', 'Attrition_Status', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Per_Annum', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive', 'Contacts_Count',
#        'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy',
#        'Total_Trans_Amt', 'Total_Trans_Ct'],
#       dtype='object')

# %%
df.shape
# Out:
# (10127, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client_Number             10127 non-null  int64
#  1   Attrition_Status          10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Per_Annum          10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive           10127 non-null  int64
#  12  Contacts_Count            10127 non-null  int64
# ...

# %%
## FROM THIS, WE CAN SEE THAT THERE ARE N0 NULL VALUES AND ALL THE COLUMNS ARE IN THEIR RIGHT DATATYPE.

# %%
df.head()
# Out:
#    Client_Number   Attrition_Status  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Per_Annum Card_Category  \
# 0     High School        Married      $60K - $80K          Blue
# 1        Graduate         Single   Less than $40K          Blue
# 2        Graduate        Married     $80K - $120K          Blue
# 3     High School        Unknown   Less than $40K          Blue
# 4      Uneducated        Married      $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive  Contacts_Count  \
# ...

# %% [markdown]
# ## START EDA

# %%
df.Attrition_Status.unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
Attrited = df[df.Attrition_Status == 'Attrited Customer']

# %%
Attrited.shape
# Out:
# (1627, 18)

# %%
Existing = df[df.Attrition_Status == 'Existing Customer']

# %%
Existing.shape
# Out:
# (8500, 18)

# %%
# USING INCOME_PER_ANNUM AS A METRIC TO KNOW WHAT COULD CAUSE THE CUSTOMERS ATTRITION

# %%
df.Income_Per_Annum.unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
value_counts = df.Income_Per_Annum.value_counts()

# %%
df.Income_Per_Annum.value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Per_Annum, dtype: int64

# %%
# WE CAN SEE THAT MOST OF THE CUSTOMERS EARN LESS THAT $40,000 PER ANNUM, WE HAVE TO PREPARe A BARCHART TO VISUALIZE IT

# %%
sns.barplot(x=value_counts.index, y=value_counts.values)
plt.title('INCOME PER ANNUM CATEGORY VIZ')
plt.ylabel('Count Of Customers')
plt.xticks(rotation=45)
plt.show()

# %%
# AFTER CHECKING THE INCOME CATEGORY OF THE MAIN DATA FRAME, WE CAN SEE THAT MOST OF OUR CUSTOMERS EARN LESS THAT $40,OOO
# HOWEVER, WE HAVE TO CHECK THE INCOME CATEGORY OF OUR EXISTING AND ATTRITED CUSTOMERS TO GET AN INSIGHT ABOUT IT.

# %%
Existing.Income_Per_Annum.value_counts()
# Out:
# Less than $40K    2949
# $40K - $60K       1519
# $80K - $120K      1293
# $60K - $80K       1213
# Unknown            925
# $120K +            601
# Name: Income_Per_Annum, dtype: int64

# %%
val_counts = Existing.Income_Per_Annum.value_counts()

# %%
sns.barplot(x=val_counts.index, y=val_counts.values)
plt.title('INCOME PER ANNUM CATEGORY VIZ')
plt.ylabel('Count Of Customers')
plt.xticks(rotation=45)
plt.show()

# %%
Attrited.Income_Per_Annum.value_counts()
# Out:
# Less than $40K    612
# $40K - $60K       271
# $80K - $120K      242
# $60K - $80K       189
# Unknown           187
# $120K +           126
# Name: Income_Per_Annum, dtype: int64

# %%
v_counts = Attrited.Income_Per_Annum.value_counts()

# %%
sns.barplot(x=v_counts.index, y=v_counts.values)
plt.title('INCOME PER ANNUM CATEGORY VIZ')
plt.ylabel('Count Of Customers')
plt.xticks(rotation=45)
plt.show()

# %%
# WE CAN SEE FROM THE ABOVE THAT BOTH OUR EXISTING AND ATTRITED CUSTOMERS MAKE LESS THAN $40,000 ANNUALLY
# WHAT THIS MEANS IS THAT THEIR ANNUAL INCOME HAS NOTHING TO DO WITH WHAT COULD MAKE SOME CUSTOMERS CHURN THE BANK

# %%
df.head()
# Out:
#    Client_Number   Attrition_Status  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Per_Annum Card_Category  \
# 0     High School        Married      $60K - $80K          Blue
# 1        Graduate         Single   Less than $40K          Blue
# 2        Graduate        Married     $80K - $120K          Blue
# 3     High School        Unknown   Less than $40K          Blue
# 4      Uneducated        Married      $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive  Contacts_Count  \
# ...

# %%
# NEXT WE HAVE TO EXPLORE THE AGE BRACKET OF OUR CUSTOMERS

# %%
df_age = df.Customer_Age.value_counts().sort_index()

# %%
# CHECK FOR THE EXISTING CUSTOMERS

# %%
Ex_age = Existing.Customer_Age.value_counts().sort_index()

# %%
Attrited.Customer_Age.value_counts().sort_index()
# Out:
# 26     6
# 27     3
# 28     1
# 29     7
# 30    15
# 31    13
# 32    17
# 33    20
# 34    19
# 35    21
# 36    24
# 37    37
# 38    47
# 39    48
# 40    64
# 41    76
# 42    62
# 43    85
# 44    84
# 45    79
# 46    82
# 47    76
# 48    85
# 49    79
# 50    71
# 51    58
# 52    58
# 53    59
# 54    69
# 55    51
# 56    43
# 57    33
# 58    24
# 59    40
# 60    13
# 61    17
# 62    17
# 63     8
# 64     5
# 65     9
# 66     1
# 68     1
# Name: Customer_Age, dtype: int64

# %%
# FROM THIS WE CAN SEE THAT CUSTORMERS THAT CHURNED THE BANK ARE BETWEEN THE AGE BRACKET OF 37 TO 59
# WHAT THIS MEANS IS THESE INDIVIDUALS ARE MATURED AND POSSIBLY WITH A FAMILY AND MOST OF WHICH EARN LESS THAT $40,000/ANN

# %%
df.head()
# Out:
#    Client_Number   Attrition_Status  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Per_Annum Card_Category  \
# 0     High School        Married      $60K - $80K          Blue
# 1        Graduate         Single   Less than $40K          Blue
# 2        Graduate        Married     $80K - $120K          Blue
# 3     High School        Unknown   Less than $40K          Blue
# 4      Uneducated        Married      $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive  Contacts_Count  \
# ...

# %%
# Next is to know the level of dependents the attrited custormers have.

# %%
Attrited.Dependent_count.unique()
# Out:
# array([0, 1, 2, 4, 5, 3], dtype=int64)

# %%
att = Attrited.Dependent_count.value_counts()

# %%
sns.barplot(x= att.index, y = att.values)
plt.xlabel('Number of Dependents')
plt.ylabel('Count of Customers')
plt.title('Count of Dependents of Customers')
plt.show()

# %%
# From this we can see that most of the customers that attrited have 3 or 2 dependents that they are responsible for
# What this means is that these custormers have other individuals they take care of asides themselves and 
# They may have to spend more money on these dependents than would have been if they had none

# %%
df.head()
# Out:
#    Client_Number   Attrition_Status  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Per_Annum Card_Category  \
# 0     High School        Married      $60K - $80K          Blue
# 1        Graduate         Single   Less than $40K          Blue
# 2        Graduate        Married     $80K - $120K          Blue
# 3     High School        Unknown   Less than $40K          Blue
# 4      Uneducated        Married      $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive  Contacts_Count  \
# ...

# %%
# MAKE AN ANALYSIS ON THE MARITAL STATUS OF BOTH THE EXISTING CUSTOMERS AND THE ATTRITED CUSTOMERS
# WE WILL DO THIS TO KNOW IF THERE ARE SOME SORT OF INCONSISTENCY BETWEEN BOTH METRICS

# %%
ex = Existing.Marital_Status.value_counts()

# %%
plt.pie(ex, labels=ex.index, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
# NOW THE ANALYSIS FOR THE ATTRITED CUSTOMERS

# %%
vc = Attrited.Marital_Status.value_counts()

# %%
plt.pie(vc, labels=vc.index, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
# JUDGING FROM THIS PIE CHART DISTRIBUTION, WE CAN SEE THAT THE CUSTOMERS THAT CHURNED THE BANK HAVE THEIR MARITAL STATUS
# DISTRIBUTED 50/50 BECAUSE THE DIFFERENCE BETWEEN THE MARRIED AND SINGLE IS VERY SLIM, SO WE CANNOT COME TO A CONCLUSION
# USING THIS METRIC
# BESIDES,MOST OF THE CLIENTS THAT ARE EXISTING ARE MARRIED, SO WE CANT SAY MARRIAGE AFFECTED THEIR REASON TO CHURN

# %%
df.head()
# Out:
#    Client_Number   Attrition_Status  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Per_Annum Card_Category  \
# 0     High School        Married      $60K - $80K          Blue
# 1        Graduate         Single   Less than $40K          Blue
# 2        Graduate        Married     $80K - $120K          Blue
# 3     High School        Unknown   Less than $40K          Blue
# 4      Uneducated        Married      $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive  Contacts_Count  \
# ...

# %%
credit_report = Attrited[['Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Trans_Ct']]

# %%
pd.set_option('display.max_rows', None)

# %%
credit_report
# Out:
#        Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Ct
# 21           1438.3                    0           1438.3              16
# 39           7882.0                  605           7277.0              16
# 51           1438.3                  808            630.3              19
# 54          15769.0                    0          15769.0              15
# 61          34516.0                    0          34516.0              15
# 82           2158.0                    0           2158.0              12
# 99           5449.0                 1628           3821.0              18
# 127         11669.0                 2227           9442.0              23
# 140          8025.0                    0           8025.0              18
# 144         14979.0                    0          14979.0              10
# 145          2732.0                    0           2732.0              16
# 168         32975.0                 2517          30458.0              17
# ...

# %%
credit_report.Total_Revolving_Bal.max()
credit_report.Total_Revolving_Bal.min()
# Out:
# 0

# %%
credit_report.Total_Revolving_Bal.value_counts().sort_index().head()
# Out:
# 0      893
# 132      1
# 134      1
# 145      1
# 154      1
# Name: Total_Revolving_Bal, dtype: int64

# %%
Attrited.shape
# Out:
# (1627, 18)

# %%
# what we can make of this is that of the 1627 customers that churned only 893 do not owe the bank
# that means 734 of these attrited customers owe the bank

# %%
## Next thing to do is check the credit report for our existing customers

# %%
credit_report2 = Existing[['Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Trans_Ct']]

# %%
credit_report2.Total_Revolving_Bal.value_counts().sort_index().head()
# Out:
# 0      1577
# 429       1
# 451       1
# 456       1
# 461       1
# Name: Total_Revolving_Bal, dtype: int64

# %%
pd.reset_option('display.max_rows')

# %%
## Most of our existing customers owe us too because of the 8500 existing customers, only 1577 are not oweing the bank
## leaving 6923 oweing the bank and are still existing.

# %% [markdown]
# ### **THEORY OF ANALYSIS**

# %% [markdown]
# #### - INITIALLY, WHAT WE ARE INTERESTED IN, OR THE BOTTOM LINE OF THIS ANALYSIS IS TO KNOW WHAT COULD BE A PRINCIPAL REASON AS TO WHY SOME OF OUR CUSTOMERS STOP USING OUR CREDIT CARD SERVICE.
# #### -THERE ARE VARIOUS REASONS THAT CAN CAUSE SUCH DECISION TO CHURN THE BANK SOME OF WHICH COULD RANGE FROM SOCIAL REASONS TO TRANSACTIONAL REASONS (ECONOMICAL).
# #### - WE KNOW FOR A FACT THAT THE ONLY LOGICAL REASON FOR THEM CHURNING THE BANK HAS TO DO WITH A SOCIOECONOMIC CAUSE, THEREFORE, WE HAVE TO MAKE A SOCIOECONOMICAL ANALYSIS TO FIND OUT WHY.
#
# ##### > FIRSTLY, JUST LIKE ANY GOOD ANALYSIS, THE DATA CLEANING HAS TO BE DONE.
# ##### >  AN ANALYSIS WAS DONE ON THE INCOME PER ANNUM OF ALL CUSTOMERS AND WE FOUND OUT THAT MOST OF OUR CUSTOMERS MAKE LESS THAN 40,000 DOLLARS, THIS SAME ANALYSIS APPLIED TO BOTH EXISTING AND ATTRITED CUSTOMERS WHICH MEANS THEIR ANNUAL REVENUE HAS LITTLE OR NOTHING TO DO WITH THEIR DECISION TO CHURN.
# ##### > ANOTHER METRIC WE EXPLORED WAS TO KNOW THE AGE BRACKET OF THE CUSTOMERS THAT ATTRITED AND WE FOUND OUT THAT MOST OF THEM ARE BETWEEN THE AGE OF 37-59, THIS GIVES US AN INSIGHT THAT THESE ARE MATURED INDIVIDUALS WHO MOST LIKELY HAVE A FAMILY THEY TAKE CARE OF WHICH BREEDS A NEED TO EXTENSIVELY MAKE USE OF THEIR CREDIT CARDS.
# ##### > SPEAKING OF FAMILIES, WE MADE AN ANALYSIS TO KNOW THE RATIO OF CUSTOMERS WITH FAMILIES AND ONES THAT ARE STILL SINGLE AND ALSO THEIR NUMBER OF DEPENDENTS, THE RESULT CAME OUT AS MOST OF OUR EXISTING CUSTOMERS ARE MARRIED AND WITH 2-3 DEPENDENTS WHILE CUSTOMERS THAT ATTRITED HAVE THE DISTRIBUTION AT 50/50 WITH SOME OF THEM HAVING 3 DEPENDENTS OR 2-3, WHAT THIS MEANS IS THAT WE CAN NOT USE THEIR SOCIAL LIFE AS A PRINCIPAL REASON FOR THE ATTRITED CUSTOMERS CHURING THE CREDIT CARD SERVICE. WE ONLY KNOW THEY HAVE A REASON TO REALLY USE THE SERVICE.
# ##### > WHAT WE ARE LEFT WITH IS TO ENGAGE IN A TRANSACTIONAL ANALYSIS WHICH BRINGS US TO THE ECONOMICAL PART OF THE ANALYSIS. THE INSIGHT WE BROUGHT OUT IS THAT OF THE 1600+ CUSTOMERS THAT CHURNED THE BANK CREDIT CARD SERVICE, 890+ OF THEM DO NOT OWE THE ORGANIZATION AS THEIR TOTAL REVOLVING BALANCE OR CURRENT ACCOUNT INDICATES 0 WHICH MEANS A LITTLE MORE THAN HALF OF THEM DO NOT OWE THE BANK, HOWEVER, OF OUR EXISTING CUSTOMERS OR THE ACTIVE CUSTOMERS, JUST 1700+ OF THE 8500 OF THEM DO NOT OWE THE ORGANIZATION BECAUSE THEIR TOTAL REVOLVING BALANCE OR CURRENT BALANCE INDICATES SO, WHAT THIS MEANS PRIMARILY IS THAT, OUR EXISTING CUSTOMERS ARE STILL WITH US BECAUSE THEY ARE STILL ACTIVELY INVOLVED IN USING THE CREDIT CARD TO NAVIGATE THEIR LIVES AND THE ONES THAT LEFT ARE NOT REALLY "A FAN" OF USING CREDIT CARDS POSSIBLY BECAUSE THEY DO NOT WANT TO ENTERTAIN OWING THE BANK AND THE ONES THAT EVEN OWE THE BANK LEFT BECAUSE THEY OWE THE BANK.
#
# #### **SOLUTION**: THE PRIMARY SOLUTION IS TO REORIENTATE OUR CUSTOMERS ON THE NEED TO ONLY USE THEIR CREDIT CARDS WHEN EXTREMELY NECESSARY AND ALSO TO PAY UP ON THEIR CURRENT BALANCE. REORIENTATION IS A VERY VITAL TECHNIC THAT WORKS PSYCHOLOGICALLY.
# #### ALSO THERE IS NEED TO CONTACT OUR ATTRITED CUSTOMERS AND REMIND THEM OF HOW WELL WE ARE WILLING TO SERVE THEM MORE IF THEY CHOOSE TO COME BACK TO USING OUR SERVICE, WE ALSO HAVE TO OFFER INCENTIVES THAT WILL BE OF VALUE TO BOTH PARTIES. IF THESE CHURNING CUSTOMERS ARE BACK IN THE SYSTEM, OUR REORIENTATION TECHNIC WILL ALSO PROPEL THEM TO MAKE VALUEABLE CHOICES AND ALSO PAY UP THEIR CURRENT BALANCE.
#
# # ANALYSIS BY: GABRIEL STEVEN OLUWAPELUMI
